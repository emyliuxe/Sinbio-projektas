# %%
import pandas as pd
print("Pandas imported successfully, version: "+pd.__version__)
import scipy as sm
from scipy.stats import *
print("SciPy imported successfully, version: "+sm.__version__)
import plotly
print("Plotly imported successfully, version: "+plotly.__version__)
from plotly.graph_objs import * # for importing the different types of plots

from sklearn.decomposition import PCA #For performing principle component analysis

# The following are necessary to run plotly in an offline mode, because its otherwise an online plotting library
from plotly.graph_objs import Scatter, Layout
plotly.offline.init_notebook_mode(connected=True)
# Out:
# Pandas imported successfully, version: 0.23.4
# SciPy imported successfully, version: 1.1.0
# Plotly imported successfully, version: 3.4.2
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
#Importuoju savo rats duomenis
data_all = pd.read_csv("/home/emilija/Dokumentai/Magistras/SinBio/Sinbio-projektas/Pilni_ziurkiu_duomenys.csv")

# %%
#Pasiziuriu, kas cia gero
data_all
#Atrodo viskas ok
# Out:
#     index    Nr         Rūšis                         Vieta  Pagavimo_data  \
# 0      11  R132      R.rattus    Zarasų raj., Pakniškių km.     2015.08.26
# 1      12  R133      R.rattus    Zarasų raj., Pakniškių km.     2015.08.26
# 2      34  R155      R.rattus    Zarasų raj., Pakniškių km.     2014.11.05
# 3      36  R157      R.rattus    Zarasų raj., Pakniškių km.     2015.10.02
# 4      37  R158      R.rattus    Zarasų raj., Pakniškių km.     2015.10.02
# 5      38  R159      R.rattus    Zarasų raj., Pakniškių km.     2015.10.02
# 6      39  R160      R.rattus    Zarasų raj., Pakniškių km.     2015.10.03
# 7      40  R161      R.rattus    Zarasų raj., Pakniškių km.     2015.10.03
# 8      41  R162      R.rattus    Zarasų raj., Pakniškių km.     2015.10.12
# 9      42  R163      R.rattus    Zarasų raj., Pakniškių km.     2015.10.12
# 10     43  R164      R.rattus    Zarasų raj., Pakniškių km.     2015.10.13
# 11     44  R165      R.rattus    Zarasų raj., Pakniškių km.     2015.10.13
# 12     45  R166      R.rattus    Zarasų raj., Pakniškių km.     2015.10.13
# 13     46  R167      R.rattus    Zarasų raj., Pakniškių km.     2015.10.13
# 14     47  R168      R.rattus    Zarasų raj., Pakniškių km.     2015.10.14
# 15     48  R169      R.rattus    Zarasų raj., Pakniškių km.     2015.10.14
# 16     50  R171  R.norvegicus                 Vilniaus raj.     2015.02.15
# 17     51  R172  R.norvegicus                 Vilniaus raj.     2015.02.16
# 18     52  R173  R.norvegicus                 Vilniaus raj.     2015.02.17
# 19     53  R174  R.norvegicus   Grubupių km., Šilutės raj.      2014.01.03
# 20     54  R175  R.norvegicus   Grubupių km., Šilutės raj.      2014.01.03
# 21     55  R176  R.norvegicus   Grubupių km., Šilutės raj.      2014.01.03
# 22     56  R177  R.norvegicus   Grubupių km., Šilutės raj.      2014.01.03
# 23     57  R178  R.norvegicus   Grubupių km., Šilutės raj.      2014.01.03
# 24     58  R179  R.norvegicus   Grubupių km., Šilutės raj.      2014.01.03
# 25     59  R180      R.rattus   Zarasų raj., Antazavės gyv.     2016.01.09
# 26     60  R181      R.rattus   Zarasų raj., Antazavės gyv.     2016.01.09
# 27     61  R182      R.rattus   Zarasų raj., Antazavės gyv.     2016.01.09
# 28     62  R183      R.rattus   Zarasų raj., Antazavės gyv.     2016.01.09
# 29     63  R184      R.rattus    Zarasų raj., Pakniškių km.     2016.01.10
# ..    ...   ...           ...                           ...            ...
# 50     87  R208      R.rattus    Zarasų raj., Pakniškių km.     2016.11.02
# 51     88  R209      R.rattus    Zarasų raj., Pakniškių km.  2017.04.05-07
# 52     89  R210      R.rattus    Zarasų raj., Pakniškių km.  2017.04.05-07
# 53     90  R211      R.rattus    Zarasų raj., Pakniškių km.  2017.03.04-07
# 54     91  R212      R.rattus    Zarasų raj., Pakniškių km.  2017.03.04-07
# 55     92  R213      R.rattus    Zarasų raj., Pakniškių km.  2017.03.04-07
# 56     93  R214      R.rattus    Zarasų raj., Pakniškių km.     2017.03.31
# 57     94  R215      R.rattus    Zarasų raj., Pakniškių km.     2017.03.31
# 58     95  R216      R.rattus    Zarasų raj., Pakniškių km.     2017.03.31
# 59     96  R217      R.rattus    Zarasų raj., Pakniškių km.     2017.02.20
# 60     97  R218      R.rattus    Zarasų raj., Pakniškių km.     2017.02.20
# 61     98  R219      R.rattus    Zarasų raj., Pakniškių km.     2017.05.01
# 62     99  R220      R.rattus    Zarasų raj., Pakniškių km.     2017.05.01
# 63    100  R221      R.rattus    Zarasų raj., Pakniškių km.     2017.02.25
# 64    101  R222      R.rattus    Zarasų raj., Pakniškių km.     2017.07.08
# 65    102  R223      R.rattus    Zarasų raj., Pakniškių km.     2017.07.08
# 66    103  R224  R.norvegicus  Rokiškio raj., Laibgalių km.     2017.09.07
# 67    104  R225  R.norvegicus  Rokiškio raj., Laibgalių km.     2017.09.07
# 68    105  R226  R.norvegicus  Rokiškio raj., Laibgalių km.     2017.09.07
# 69    106  R227  R.norvegicus  Rokiškio raj., Laibgalių km.     2017.09.07
# 70    107  R228  R.norvegicus  Rokiškio raj., Laibgalių km.     2017.09.07
# 71    108  R229  R.norvegicus  Rokiškio raj., Laibgalių km.     2017.09.07
# 72    109  R230  R.norvegicus  Rokiškio raj., Laibgalių km.     2017.09.07
# 73    110  R231  R.norvegicus  Rokiškio raj., Laibgalių km.     2017.09.07
# 74    111  R232  R.norvegicus  Rokiškio raj., Laibgalių km.     2017.09.07
# 75    112  R233  R.norvegicus  Rokiškio raj., Laibgalių km.     2017.09.07
# 76    113  R234      R.rattus   Zarasų raj., Antazavės gyv.     2017.09.20
# 77    114  R235      R.rattus      Zarasų raj., Dusetų gyv.     2017.09.28
# 78    115  R236      R.rattus    Zarasų raj., Pakniškių km.     2017.09.30
# 79    116  R237      R.rattus    Zarasų raj., Pakniškių km.     2017.10.01
#
#    Lytis       Q(g.)       L(mm)     Luo(mm)      P(mm)      A(mm) Amžius  \
# 0   mot.   73.000000  130.000000  158.000000  33.000000  18.000000   sub.
# 1   mot.   35.000000  105.000000  127.000000  28.000000  15.000000   juv.
# 2   mot.   67.000000  137.000000  149.000000  34.000000  18.000000   juv.
# 3   mot.   86.000000  158.000000  187.000000  34.000000  18.000000   sub.
# 4   mot.   55.000000  124.000000  146.000000  32.000000  17.000000   juv.
# 5   vyr.   79.000000  140.000000  170.000000  33.000000  21.000000   juv.
# 6   mot.   35.000000  115.000000  128.000000  28.000000  16.000000   juv.
# 7   vyr.   32.000000  110.000000  121.000000  29.000000  17.000000   juv.
# 8   mot.   35.000000  113.000000  127.000000  29.000000  16.000000   juv.
# 9   mot.   21.000000   88.000000  101.000000  23.000000  15.000000   juv.
# 10  mot.  111.000000  178.610990  202.000000  38.000000  18.000000    ad.
# 11  mot.   28.000000   98.000000  134.000000  29.000000  17.000000   juv.
# 12  mot.   30.000000  101.000000  127.000000  27.000000  18.000000   juv.
# 13  vyr.   45.536869  124.817069  134.000000  30.000000  17.158561   juv.
# 14  vyr.   32.000000  110.000000  124.000000  30.000000  17.000000   juv.
# 15  vyr.   24.000000  103.000000  113.000000  26.000000  15.000000   juv.
# 16  vyr.  351.000000  227.000000  216.000000  42.000000  19.000000    ad.
# 17  vyr.  421.000000  249.000000  172.000000  42.000000  21.000000    ad.
# 18  vyr.  384.000000  235.000000  200.000000  41.000000  20.000000    ad.
# 19  vyr.  285.000000  211.000000  175.000000  39.000000  17.000000    ad.
# 20  mot.  292.000000  202.000000  175.000000  40.000000  20.000000    ad.
# 21  vyr.  433.000000  235.000000  205.000000  45.000000  18.000000    ad.
# 22  vyr.  435.000000  242.000000  195.000000  44.000000  19.929638    ad.
# 23  vyr.  408.000000  230.000000  179.000000  42.000000  22.000000    ad.
# 24  vyr.  332.000000  220.000000  192.000000  40.000000  20.000000    ad.
# 25  vyr.  105.000000  165.000000  186.000000  32.000000  21.000000   sub.
# 26  vyr.  111.000000  173.000000  194.000000  33.000000  18.000000    ad.
# 27  vyr.  107.000000  162.000000  162.000000  33.000000  18.000000    ad.
# 28  mot.   98.000000  165.000000  190.000000  35.000000  21.000000   sub.
# 29  mot.  140.000000  179.000000  220.000000  36.000000  24.000000    ad.
# ..   ...         ...         ...         ...        ...        ...    ...
# 50  vyr.  230.000000  202.000000  201.000000  37.000000  27.000000    ad.
# 51  vyr.  154.000000  166.673643  165.074978  35.077765  18.914919    ad.
# 52  mot.   82.000000  142.749506  153.470559  32.215940  18.431860   sub.
# 53  mot.   92.000000  146.072303  155.082284  32.613416  18.498951   sub.
# 54  mot.   42.000000  129.458319  147.023659  30.626037  18.163494   juv.
# 55  mot.  177.000000  174.316076  168.781946  35.991959  19.069229    ad.
# 56  vyr.   75.000000  140.423548  152.342351  31.937707  18.384896   juv.
# 57  vyr.   48.000000  131.451997  147.990694  30.864523  18.203749   juv.
# 58  mot.   41.000000  129.126039  146.862486  30.586290  18.156785   juv.
# 59  mot.  138.000000  161.357168  162.496218  34.441804  18.807572    ad.
# 60  mot.   77.000000  141.088108  152.664696  32.017202  18.398314   juv.
# 61  vyr.  136.000000  160.692609  162.173873  34.362309  18.794154    ad.
# 62  mot.   83.000000  143.081786  153.631731  32.255688  18.438569   sub.
# 63  mot.   33.000000  126.467802  145.573106  30.268309  18.103112   juv.
# 64  mot.  137.000000  161.024889  162.335046  34.402056  18.800863    ad.
# 65  mot.  122.000000  156.040693  159.917459  33.805843  18.700226   sub.
# 66  vyr.  369.000000  230.000000  199.000000  45.000000  18.000000    ad.
# 67  mot.  231.000000  186.000000  174.000000  40.000000  20.000000    ad.
# 68  vyr.  384.000000  245.000000  200.000000  47.000000  20.000000    ad.
# 69  mot.  286.000000  209.000000  185.403075  40.000000  19.788912    ad.
# 70  vyr.  336.000000  240.000000  160.000000  42.000000  21.000000    ad.
# 71  vyr.  305.000000  225.000000  190.000000  45.000000  18.000000    ad.
# 72  mot.  252.000000  200.000000  170.000000  40.000000  20.000000    ad.
# 73  mot.   80.000000  150.000000  115.000000  35.000000  17.000000   sub.
# 74  vyr.  102.000000  167.000000  125.000000  32.000000  11.000000   sub.
# 75  vyr.   73.000000  145.000000  120.000000  35.000000  18.000000   juv.
# 76  mot.  104.000000  165.000000  160.000000  32.000000  20.000000   sub.
# 77  mot.  130.000000  170.000000  176.000000  35.000000  19.000000   sub.
# 78  mot.  137.000000  170.000000  195.000000  36.000000  25.000000   sub.
# 79  vyr.   47.000000  130.000000  135.000000  32.000000  21.000000   juv.
#
#                              Pastabos RatPyV1 RatPyV2
# 0            Tvartas, laikomos vištos      Ne      Ne
# 1            Tvartas, laikomos vištos      Ne      Ne
# 2            Tvartas, laikomos vištos      Ne      Ne
# 3                   Gyvenamasis namas      Ne      Ne
# 4                   Gyvenamasis namas      Ne      Ne
# 5                   Gyvenamasis namas      Ne      Ne
# 6                   Gyvenamasis namas      Ne      Ne
# 7                   Gyvenamasis namas      Ne    Taip
# 8            Tvartas, laikomos vištos      Ne      Ne
# 9            Tvartas, laikomos vištos      Ne      Ne
# 10           Tvartas, laikomos vištos      Ne      Ne
# 11           Tvartas, laikomos vištos      Ne    Taip
# 12           Tvartas, laikomos vištos      Ne    Taip
# 13           Tvartas, laikomos vištos      Ne      Ne
# 14           Tvartas, laikomos vištos      Ne      Ne
# 15           Tvartas, laikomos vištos      Ne    Taip
# 16          Tvartas, laikomos kiaulės      Ne      Ne
# 17          Tvartas, laikomos kiaulės      Ne      Ne
# 18          Tvartas, laikomos kiaulės      Ne      Ne
# 19        Kiaulių auginimo kompleksas    Taip      Ne
# 20        Kiaulių auginimo kompleksas    Taip      Ne
# 21        Kiaulių auginimo kompleksas    Taip      Ne
# 22        Kiaulių auginimo kompleksas      Ne      Ne
# 23        Kiaulių auginimo kompleksas      Ne      Ne
# 24        Kiaulių auginimo kompleksas      Ne      Ne
# 25           Tvartas, laikomos karvės      Ne      Ne
# 26           Tvartas, laikomos karvės      Ne      Ne
# 27           Tvartas, laikomos karvės      Ne      Ne
# 28           Tvartas, laikomos karvės      Ne      Ne
# 29           Tvartas, laikomos karvės      Ne      Ne
# ..                                ...     ...     ...
# 50           Tvartas, laikomos vištos      Ne      Ne
# 51           Tvartas, laikomos vištos      Ne      Ne
# 52           Tvartas, laikomos vištos      Ne      Ne
# 53           Tvartas, laikomos vištos      Ne      Ne
# 54           Tvartas, laikomos vištos      Ne      Ne
# 55           Tvartas, laikomos vištos      Ne      Ne
# 56           Tvartas, laikomos vištos      Ne      Ne
# 57           Tvartas, laikomos vištos      Ne      Ne
# 58           Tvartas, laikomos vištos      Ne      Ne
# 59           Tvartas, laikomos vištos      Ne      Ne
# 60           Tvartas, laikomos vištos    Taip      Ne
# 61           Tvartas, laikomos vištos      Ne      Ne
# 62           Tvartas, laikomos vištos      Ne      Ne
# 63           Tvartas, laikomos vištos      Ne      Ne
# 64           Tvartas, laikomos vištos      Ne      Ne
# 65           Tvartas, laikomos vištos      Ne      Ne
# 66                         Paukštynas      Ne      Ne
# 67                         Paukštynas      Ne      Ne
# 68                         Paukštynas    Taip      Ne
# 69                         Paukštynas      Ne    Taip
# 70                         Paukštynas      Ne      Ne
# 71                         Paukštynas      Ne      Ne
# 72                         Paukštynas    Taip      Ne
# 73                         Paukštynas      Ne      Ne
# 74                         Paukštynas      Ne      Ne
# 75                         Paukštynas      Ne      Ne
# 76           Tvartas, laikomos karvės      Ne      Ne
# 77  Ūkinis pastatas, gyvūnų nelaikoma      Ne      Ne
# 78           Tvartas, laikomos vištos      Ne      Ne
# 79           Tvartas, laikomos vištos      Ne      Ne
#
# [80 rows x 15 columns]

# %%
data_all.describe()
# Out:
#             index       Q(g.)       L(mm)     Luo(mm)      P(mm)      A(mm)
# count   80.000000   80.000000   80.000000   80.000000  80.000000  80.000000
# mean    74.187500  151.744211  165.380657  164.272802  34.918336  18.809298
# std     25.987871  117.636167   41.535664   29.110053   5.145127   2.752830
# min     11.000000   21.000000   88.000000  101.000000  23.000000  11.000000
# 25%     53.750000   65.750000  131.338998  146.646865  31.984427  18.000000
# 50%     74.500000  109.000000  163.500000  163.748109  34.382182  18.468760
# 75%     96.250000  231.500000  197.750000  187.500000  39.250000  20.000000
# max    116.000000  435.000000  249.000000  231.000000  47.000000  27.000000

# %%
data_all.describe(include='all')
# Out:
#              index    Nr     Rūšis                       Vieta Pagavimo_data  \
# count    80.000000    80        80                          80            80
# unique         NaN    80         2                          10            36
# top            NaN  R217  R.rattus  Zarasų raj., Pakniškių km.    2017.09.07
# freq           NaN     1        54                          46            10
# mean     74.187500   NaN       NaN                         NaN           NaN
# std      25.987871   NaN       NaN                         NaN           NaN
# min      11.000000   NaN       NaN                         NaN           NaN
# 25%      53.750000   NaN       NaN                         NaN           NaN
# 50%      74.500000   NaN       NaN                         NaN           NaN
# 75%      96.250000   NaN       NaN                         NaN           NaN
# max     116.000000   NaN       NaN                         NaN           NaN
#
#        Lytis       Q(g.)       L(mm)     Luo(mm)      P(mm)      A(mm) Amžius  \
# count     80   80.000000   80.000000   80.000000  80.000000  80.000000     80
# unique     2         NaN         NaN         NaN        NaN        NaN      3
# top     vyr.         NaN         NaN         NaN        NaN        NaN    ad.
# freq      42         NaN         NaN         NaN        NaN        NaN     36
# mean     NaN  151.744211  165.380657  164.272802  34.918336  18.809298    NaN
# std      NaN  117.636167   41.535664   29.110053   5.145127   2.752830    NaN
# min      NaN   21.000000   88.000000  101.000000  23.000000  11.000000    NaN
# 25%      NaN   65.750000  131.338998  146.646865  31.984427  18.000000    NaN
# 50%      NaN  109.000000  163.500000  163.748109  34.382182  18.468760    NaN
# 75%      NaN  231.500000  197.750000  187.500000  39.250000  20.000000    NaN
# max      NaN  435.000000  249.000000  231.000000  47.000000  27.000000    NaN
#
#                         Pastabos RatPyV1 RatPyV2
# count                         80      80      80
# unique                         8       2       2
# top     Tvartas, laikomos vištos      Ne      Ne
# freq                          39      70      75
# mean                         NaN     NaN     NaN
# std                          NaN     NaN     NaN
# min                          NaN     NaN     NaN
# 25%                          NaN     NaN     NaN
# 50%                          NaN     NaN     NaN
# 75%                          NaN     NaN     NaN
# max                          NaN     NaN     NaN

# %%
data_all.Rūšis.describe()
# Out:
# count           80
# unique           2
# top       R.rattus
# freq            54
# Name: Rūšis, dtype: object

# %%
data_all.Vieta.describe()
# Out:
# count                             80
# unique                            10
# top       Zarasų raj., Pakniškių km.
# freq                              46
# Name: Vieta, dtype: object

# %%
data_all.Lytis.describe()
# Out:
# count       80
# unique       2
# top       vyr.
# freq        42
# Name: Lytis, dtype: object

# %%
data_all.Amžius.describe()
# Out:
# count      80
# unique      3
# top       ad.
# freq       36
# Name: Amžius, dtype: object

# %%
data_all.iloc[:,3].describe()
# Out:
# count                             80
# unique                            10
# top       Zarasų raj., Pakniškių km.
# freq                              46
# Name: Vieta, dtype: object

# %%
data_all.Pastabos.describe()
# Out:
# count                           80
# unique                           8
# top       Tvartas, laikomos vištos
# freq                            39
# Name: Pastabos, dtype: object

# %%
data_all.RatPyV1.describe()
# Out:
# count     80
# unique     2
# top       Ne
# freq      70
# Name: RatPyV1, dtype: object

# %%
data_all.RatPyV2.describe()
# Out:
# count     80
# unique     2
# top       Ne
# freq      75
# Name: RatPyV2, dtype: object

# %%
data_all.Pagavimo_data.min()
# Out:
# '2014.01.03'

# %%
data_all.Pagavimo_data.max()
# Out:
# '2017.10.01'

# %%
data_all.head()
# Out:
#    index    Nr     Rūšis                       Vieta Pagavimo_data Lytis  \
# 0     11  R132  R.rattus  Zarasų raj., Pakniškių km.    2015.08.26  mot.
# 1     12  R133  R.rattus  Zarasų raj., Pakniškių km.    2015.08.26  mot.
# 2     34  R155  R.rattus  Zarasų raj., Pakniškių km.    2014.11.05  mot.
# 3     36  R157  R.rattus  Zarasų raj., Pakniškių km.    2015.10.02  mot.
# 4     37  R158  R.rattus  Zarasų raj., Pakniškių km.    2015.10.02  mot.
#
#    Q(g.)  L(mm)  Luo(mm)  P(mm)  A(mm) Amžius                  Pastabos  \
# 0   73.0  130.0    158.0   33.0   18.0   sub.  Tvartas, laikomos vištos
# 1   35.0  105.0    127.0   28.0   15.0   juv.  Tvartas, laikomos vištos
# 2   67.0  137.0    149.0   34.0   18.0   juv.  Tvartas, laikomos vištos
# 3   86.0  158.0    187.0   34.0   18.0   sub.         Gyvenamasis namas
# 4   55.0  124.0    146.0   32.0   17.0   juv.         Gyvenamasis namas
#
#   RatPyV1 RatPyV2
# 0      Ne      Ne
# 1      Ne      Ne
# 2      Ne      Ne
# 3      Ne      Ne
# 4      Ne      Ne

# %%
data_all.Nr.min()
# Out:
# 'R132'

# %%
data_all.Nr.max()
# Out:
# 'R237'

# %%
data_all.Nr.count()
# Out:
# 80

# %%
data_all.Rūšis.unique()
# Out:
# array(['R.rattus', 'R.norvegicus'], dtype=object)

# %%
data_all.Vieta.unique()
# Out:
# array(['Zarasų raj., Pakniškių km.', 'Vilniaus raj.',
#        'Grubupių km., Šilutės raj. ', 'Zarasų raj., Antazavės gyv.',
#        'Vilnius, senamiestis', 'Vilnius, Gedimino pr.',
#        'Joniškio raj., Šarūnų km.', 'Rokiškio raj., Kovelių km.',
#        'Rokiškio raj., Laibgalių km.', 'Zarasų raj., Dusetų gyv.'],
#       dtype=object)

# %%
data_all.Vieta.describe()
# Out:
# count                             80
# unique                            10
# top       Zarasų raj., Pakniškių km.
# freq                              46
# Name: Vieta, dtype: object

# %%
data_all.Pagavimo_data.describe()
# Out:
# count             80
# unique            36
# top       2017.09.07
# freq              10
# Name: Pagavimo_data, dtype: object

# %%
data_all.Vieta.isna().sum()
# Out:
# 0

# %%
data_all.Lytis.isna().sum()
# Out:
# 0

# %%
data_all.Amžius.unique()
# Out:
# array(['sub.', 'juv.', 'ad.'], dtype=object)

# %%
data_all.Amžius.value_counts()
# Out:
# ad.     36
# juv.    27
# sub.    17
# Name: Amžius, dtype: int64

# %%
data_all.Amžius.isna().sum()
# Out:
# 0

# %%
data_all.Rūšis.value_counts()
# Out:
# R.rattus        54
# R.norvegicus    26
# Name: Rūšis, dtype: int64

# %%
data_all.Vieta.value_counts()
# Out:
# Zarasų raj., Pakniškių km.      46
# Rokiškio raj., Laibgalių km.    10
# Zarasų raj., Antazavės gyv.      7
# Grubupių km., Šilutės raj.       6
# Vilniaus raj.                    4
# Joniškio raj., Šarūnų km.        3
# Zarasų raj., Dusetų gyv.         1
# Rokiškio raj., Kovelių km.       1
# Vilnius, senamiestis             1
# Vilnius, Gedimino pr.            1
# Name: Vieta, dtype: int64

# %%
data_all.Pagavimo_data.value_counts()
# Out:
# 2017.09.07          10
# 2014.01.03           6
# 2016.09.27           5
# 2016.01.09           4
# 2015.10.13           4
# 2016.08.31           4
# 2017.03.31           3
# 2017.03.04-07        3
# 2015.10.02           3
# 2015.10.03           2
# 2016.09.15           2
# 2017.02.20           2
# 2015.08.26           2
# 2017.04.05-07        2
# 2016.01.10           2
# 2015.10.14           2
# 2017.07.08           2
# 2014.11.05           2
# 2017.05.01           2
# 2015.10.12           2
# 2016.04.01           1
# 2017.09.28           1
# 2016.02.05           1
# 2014.09.29-10.21     1
# 2015.02.17           1
# 2015.02.15           1
# 2016.11.02           1
# 2017.10.01           1
# 2017.09.20           1
# 2015.02.16           1
# 2015.10.05           1
# 2015.03              1
# 2014.11.06           1
# 2017.09.30           1
# 2017.02.25           1
# 2014.09.29-10.22     1
# Name: Pagavimo_data, dtype: int64

# %%
data_all.Lytis.value_counts()
# Out:
# vyr.    42
# mot.    38
# Name: Lytis, dtype: int64

# %%
data_all.Amžius.value_counts()
# Out:
# ad.     36
# juv.    27
# sub.    17
# Name: Amžius, dtype: int64

# %%
data_all.Pastabos.value_counts()
# Out:
# Tvartas, laikomos vištos             39
# Paukštynas                           11
# Tvartas, laikomos karvės              9
# Gyvenamasis namas                     7
# Kiaulių auginimo kompleksas           6
# Tvartas, laikomos kiaulės             4
# Tvartas, laikomos karvės, kiaulės     3
# Ūkinis pastatas, gyvūnų nelaikoma     1
# Name: Pastabos, dtype: int64

# %%
data_all.Pastabos.isna().sum()
# Out:
# 0

# %%
data_all.RatPyV1.isna().sum()
# Out:
# 0

# %%
data_all.RatPyV1.value_counts()
# Out:
# Ne      70
# Taip    10
# Name: RatPyV1, dtype: int64

# %%
data_all.RatPyV2.value_counts()
# Out:
# Ne      75
# Taip     5
# Name: RatPyV2, dtype: int64

# %%
data_all.RatPyV2.isna().sum()
# Out:
# 0

# %%
data_all.Pastabos.unique()
# Out:
# array(['Tvartas, laikomos vištos', 'Gyvenamasis namas',
#        'Tvartas, laikomos kiaulės', 'Kiaulių auginimo kompleksas',
#        'Tvartas, laikomos karvės', 'Tvartas, laikomos karvės, kiaulės',
#        'Paukštynas', 'Ūkinis pastatas, gyvūnų nelaikoma'], dtype=object)

# %%
data_all
# Out:
#     index    Nr         Rūšis                         Vieta  Pagavimo_data  \
# 0      11  R132      R.rattus    Zarasų raj., Pakniškių km.     2015.08.26
# 1      12  R133      R.rattus    Zarasų raj., Pakniškių km.     2015.08.26
# 2      34  R155      R.rattus    Zarasų raj., Pakniškių km.     2014.11.05
# 3      36  R157      R.rattus    Zarasų raj., Pakniškių km.     2015.10.02
# 4      37  R158      R.rattus    Zarasų raj., Pakniškių km.     2015.10.02
# 5      38  R159      R.rattus    Zarasų raj., Pakniškių km.     2015.10.02
# 6      39  R160      R.rattus    Zarasų raj., Pakniškių km.     2015.10.03
# 7      40  R161      R.rattus    Zarasų raj., Pakniškių km.     2015.10.03
# 8      41  R162      R.rattus    Zarasų raj., Pakniškių km.     2015.10.12
# 9      42  R163      R.rattus    Zarasų raj., Pakniškių km.     2015.10.12
# 10     43  R164      R.rattus    Zarasų raj., Pakniškių km.     2015.10.13
# 11     44  R165      R.rattus    Zarasų raj., Pakniškių km.     2015.10.13
# 12     45  R166      R.rattus    Zarasų raj., Pakniškių km.     2015.10.13
# 13     46  R167      R.rattus    Zarasų raj., Pakniškių km.     2015.10.13
# 14     47  R168      R.rattus    Zarasų raj., Pakniškių km.     2015.10.14
# 15     48  R169      R.rattus    Zarasų raj., Pakniškių km.     2015.10.14
# 16     50  R171  R.norvegicus                 Vilniaus raj.     2015.02.15
# 17     51  R172  R.norvegicus                 Vilniaus raj.     2015.02.16
# 18     52  R173  R.norvegicus                 Vilniaus raj.     2015.02.17
# 19     53  R174  R.norvegicus   Grubupių km., Šilutės raj.      2014.01.03
# 20     54  R175  R.norvegicus   Grubupių km., Šilutės raj.      2014.01.03
# 21     55  R176  R.norvegicus   Grubupių km., Šilutės raj.      2014.01.03
# 22     56  R177  R.norvegicus   Grubupių km., Šilutės raj.      2014.01.03
# 23     57  R178  R.norvegicus   Grubupių km., Šilutės raj.      2014.01.03
# 24     58  R179  R.norvegicus   Grubupių km., Šilutės raj.      2014.01.03
# 25     59  R180      R.rattus   Zarasų raj., Antazavės gyv.     2016.01.09
# 26     60  R181      R.rattus   Zarasų raj., Antazavės gyv.     2016.01.09
# 27     61  R182      R.rattus   Zarasų raj., Antazavės gyv.     2016.01.09
# 28     62  R183      R.rattus   Zarasų raj., Antazavės gyv.     2016.01.09
# 29     63  R184      R.rattus    Zarasų raj., Pakniškių km.     2016.01.10
# ..    ...   ...           ...                           ...            ...
# 50     87  R208      R.rattus    Zarasų raj., Pakniškių km.     2016.11.02
# 51     88  R209      R.rattus    Zarasų raj., Pakniškių km.  2017.04.05-07
# 52     89  R210      R.rattus    Zarasų raj., Pakniškių km.  2017.04.05-07
# 53     90  R211      R.rattus    Zarasų raj., Pakniškių km.  2017.03.04-07
# 54     91  R212      R.rattus    Zarasų raj., Pakniškių km.  2017.03.04-07
# 55     92  R213      R.rattus    Zarasų raj., Pakniškių km.  2017.03.04-07
# 56     93  R214      R.rattus    Zarasų raj., Pakniškių km.     2017.03.31
# 57     94  R215      R.rattus    Zarasų raj., Pakniškių km.     2017.03.31
# 58     95  R216      R.rattus    Zarasų raj., Pakniškių km.     2017.03.31
# 59     96  R217      R.rattus    Zarasų raj., Pakniškių km.     2017.02.20
# 60     97  R218      R.rattus    Zarasų raj., Pakniškių km.     2017.02.20
# 61     98  R219      R.rattus    Zarasų raj., Pakniškių km.     2017.05.01
# 62     99  R220      R.rattus    Zarasų raj., Pakniškių km.     2017.05.01
# 63    100  R221      R.rattus    Zarasų raj., Pakniškių km.     2017.02.25
# 64    101  R222      R.rattus    Zarasų raj., Pakniškių km.     2017.07.08
# 65    102  R223      R.rattus    Zarasų raj., Pakniškių km.     2017.07.08
# 66    103  R224  R.norvegicus  Rokiškio raj., Laibgalių km.     2017.09.07
# 67    104  R225  R.norvegicus  Rokiškio raj., Laibgalių km.     2017.09.07
# 68    105  R226  R.norvegicus  Rokiškio raj., Laibgalių km.     2017.09.07
# 69    106  R227  R.norvegicus  Rokiškio raj., Laibgalių km.     2017.09.07
# 70    107  R228  R.norvegicus  Rokiškio raj., Laibgalių km.     2017.09.07
# 71    108  R229  R.norvegicus  Rokiškio raj., Laibgalių km.     2017.09.07
# 72    109  R230  R.norvegicus  Rokiškio raj., Laibgalių km.     2017.09.07
# 73    110  R231  R.norvegicus  Rokiškio raj., Laibgalių km.     2017.09.07
# 74    111  R232  R.norvegicus  Rokiškio raj., Laibgalių km.     2017.09.07
# 75    112  R233  R.norvegicus  Rokiškio raj., Laibgalių km.     2017.09.07
# 76    113  R234      R.rattus   Zarasų raj., Antazavės gyv.     2017.09.20
# 77    114  R235      R.rattus      Zarasų raj., Dusetų gyv.     2017.09.28
# 78    115  R236      R.rattus    Zarasų raj., Pakniškių km.     2017.09.30
# 79    116  R237      R.rattus    Zarasų raj., Pakniškių km.     2017.10.01
#
#    Lytis       Q(g.)       L(mm)     Luo(mm)      P(mm)      A(mm) Amžius  \
# 0   mot.   73.000000  130.000000  158.000000  33.000000  18.000000   sub.
# 1   mot.   35.000000  105.000000  127.000000  28.000000  15.000000   juv.
# 2   mot.   67.000000  137.000000  149.000000  34.000000  18.000000   juv.
# 3   mot.   86.000000  158.000000  187.000000  34.000000  18.000000   sub.
# 4   mot.   55.000000  124.000000  146.000000  32.000000  17.000000   juv.
# 5   vyr.   79.000000  140.000000  170.000000  33.000000  21.000000   juv.
# 6   mot.   35.000000  115.000000  128.000000  28.000000  16.000000   juv.
# 7   vyr.   32.000000  110.000000  121.000000  29.000000  17.000000   juv.
# 8   mot.   35.000000  113.000000  127.000000  29.000000  16.000000   juv.
# 9   mot.   21.000000   88.000000  101.000000  23.000000  15.000000   juv.
# 10  mot.  111.000000  178.610990  202.000000  38.000000  18.000000    ad.
# 11  mot.   28.000000   98.000000  134.000000  29.000000  17.000000   juv.
# 12  mot.   30.000000  101.000000  127.000000  27.000000  18.000000   juv.
# 13  vyr.   45.536869  124.817069  134.000000  30.000000  17.158561   juv.
# 14  vyr.   32.000000  110.000000  124.000000  30.000000  17.000000   juv.
# 15  vyr.   24.000000  103.000000  113.000000  26.000000  15.000000   juv.
# 16  vyr.  351.000000  227.000000  216.000000  42.000000  19.000000    ad.
# 17  vyr.  421.000000  249.000000  172.000000  42.000000  21.000000    ad.
# 18  vyr.  384.000000  235.000000  200.000000  41.000000  20.000000    ad.
# 19  vyr.  285.000000  211.000000  175.000000  39.000000  17.000000    ad.
# 20  mot.  292.000000  202.000000  175.000000  40.000000  20.000000    ad.
# 21  vyr.  433.000000  235.000000  205.000000  45.000000  18.000000    ad.
# 22  vyr.  435.000000  242.000000  195.000000  44.000000  19.929638    ad.
# 23  vyr.  408.000000  230.000000  179.000000  42.000000  22.000000    ad.
# 24  vyr.  332.000000  220.000000  192.000000  40.000000  20.000000    ad.
# 25  vyr.  105.000000  165.000000  186.000000  32.000000  21.000000   sub.
# 26  vyr.  111.000000  173.000000  194.000000  33.000000  18.000000    ad.
# 27  vyr.  107.000000  162.000000  162.000000  33.000000  18.000000    ad.
# 28  mot.   98.000000  165.000000  190.000000  35.000000  21.000000   sub.
# 29  mot.  140.000000  179.000000  220.000000  36.000000  24.000000    ad.
# ..   ...         ...         ...         ...        ...        ...    ...
# 50  vyr.  230.000000  202.000000  201.000000  37.000000  27.000000    ad.
# 51  vyr.  154.000000  166.673643  165.074978  35.077765  18.914919    ad.
# 52  mot.   82.000000  142.749506  153.470559  32.215940  18.431860   sub.
# 53  mot.   92.000000  146.072303  155.082284  32.613416  18.498951   sub.
# 54  mot.   42.000000  129.458319  147.023659  30.626037  18.163494   juv.
# 55  mot.  177.000000  174.316076  168.781946  35.991959  19.069229    ad.
# 56  vyr.   75.000000  140.423548  152.342351  31.937707  18.384896   juv.
# 57  vyr.   48.000000  131.451997  147.990694  30.864523  18.203749   juv.
# 58  mot.   41.000000  129.126039  146.862486  30.586290  18.156785   juv.
# 59  mot.  138.000000  161.357168  162.496218  34.441804  18.807572    ad.
# 60  mot.   77.000000  141.088108  152.664696  32.017202  18.398314   juv.
# 61  vyr.  136.000000  160.692609  162.173873  34.362309  18.794154    ad.
# 62  mot.   83.000000  143.081786  153.631731  32.255688  18.438569   sub.
# 63  mot.   33.000000  126.467802  145.573106  30.268309  18.103112   juv.
# 64  mot.  137.000000  161.024889  162.335046  34.402056  18.800863    ad.
# 65  mot.  122.000000  156.040693  159.917459  33.805843  18.700226   sub.
# 66  vyr.  369.000000  230.000000  199.000000  45.000000  18.000000    ad.
# 67  mot.  231.000000  186.000000  174.000000  40.000000  20.000000    ad.
# 68  vyr.  384.000000  245.000000  200.000000  47.000000  20.000000    ad.
# 69  mot.  286.000000  209.000000  185.403075  40.000000  19.788912    ad.
# 70  vyr.  336.000000  240.000000  160.000000  42.000000  21.000000    ad.
# 71  vyr.  305.000000  225.000000  190.000000  45.000000  18.000000    ad.
# 72  mot.  252.000000  200.000000  170.000000  40.000000  20.000000    ad.
# 73  mot.   80.000000  150.000000  115.000000  35.000000  17.000000   sub.
# 74  vyr.  102.000000  167.000000  125.000000  32.000000  11.000000   sub.
# 75  vyr.   73.000000  145.000000  120.000000  35.000000  18.000000   juv.
# 76  mot.  104.000000  165.000000  160.000000  32.000000  20.000000   sub.
# 77  mot.  130.000000  170.000000  176.000000  35.000000  19.000000   sub.
# 78  mot.  137.000000  170.000000  195.000000  36.000000  25.000000   sub.
# 79  vyr.   47.000000  130.000000  135.000000  32.000000  21.000000   juv.
#
#                              Pastabos RatPyV1 RatPyV2
# 0            Tvartas, laikomos vištos      Ne      Ne
# 1            Tvartas, laikomos vištos      Ne      Ne
# 2            Tvartas, laikomos vištos      Ne      Ne
# 3                   Gyvenamasis namas      Ne      Ne
# 4                   Gyvenamasis namas      Ne      Ne
# 5                   Gyvenamasis namas      Ne      Ne
# 6                   Gyvenamasis namas      Ne      Ne
# 7                   Gyvenamasis namas      Ne    Taip
# 8            Tvartas, laikomos vištos      Ne      Ne
# 9            Tvartas, laikomos vištos      Ne      Ne
# 10           Tvartas, laikomos vištos      Ne      Ne
# 11           Tvartas, laikomos vištos      Ne    Taip
# 12           Tvartas, laikomos vištos      Ne    Taip
# 13           Tvartas, laikomos vištos      Ne      Ne
# 14           Tvartas, laikomos vištos      Ne      Ne
# 15           Tvartas, laikomos vištos      Ne    Taip
# 16          Tvartas, laikomos kiaulės      Ne      Ne
# 17          Tvartas, laikomos kiaulės      Ne      Ne
# 18          Tvartas, laikomos kiaulės      Ne      Ne
# 19        Kiaulių auginimo kompleksas    Taip      Ne
# 20        Kiaulių auginimo kompleksas    Taip      Ne
# 21        Kiaulių auginimo kompleksas    Taip      Ne
# 22        Kiaulių auginimo kompleksas      Ne      Ne
# 23        Kiaulių auginimo kompleksas      Ne      Ne
# 24        Kiaulių auginimo kompleksas      Ne      Ne
# 25           Tvartas, laikomos karvės      Ne      Ne
# 26           Tvartas, laikomos karvės      Ne      Ne
# 27           Tvartas, laikomos karvės      Ne      Ne
# 28           Tvartas, laikomos karvės      Ne      Ne
# 29           Tvartas, laikomos karvės      Ne      Ne
# ..                                ...     ...     ...
# 50           Tvartas, laikomos vištos      Ne      Ne
# 51           Tvartas, laikomos vištos      Ne      Ne
# 52           Tvartas, laikomos vištos      Ne      Ne
# 53           Tvartas, laikomos vištos      Ne      Ne
# 54           Tvartas, laikomos vištos      Ne      Ne
# 55           Tvartas, laikomos vištos      Ne      Ne
# 56           Tvartas, laikomos vištos      Ne      Ne
# 57           Tvartas, laikomos vištos      Ne      Ne
# 58           Tvartas, laikomos vištos      Ne      Ne
# 59           Tvartas, laikomos vištos      Ne      Ne
# 60           Tvartas, laikomos vištos    Taip      Ne
# 61           Tvartas, laikomos vištos      Ne      Ne
# 62           Tvartas, laikomos vištos      Ne      Ne
# 63           Tvartas, laikomos vištos      Ne      Ne
# 64           Tvartas, laikomos vištos      Ne      Ne
# 65           Tvartas, laikomos vištos      Ne      Ne
# 66                         Paukštynas      Ne      Ne
# 67                         Paukštynas      Ne      Ne
# 68                         Paukštynas    Taip      Ne
# 69                         Paukštynas      Ne    Taip
# 70                         Paukštynas      Ne      Ne
# 71                         Paukštynas      Ne      Ne
# 72                         Paukštynas    Taip      Ne
# 73                         Paukštynas      Ne      Ne
# 74                         Paukštynas      Ne      Ne
# 75                         Paukštynas      Ne      Ne
# 76           Tvartas, laikomos karvės      Ne      Ne
# 77  Ūkinis pastatas, gyvūnų nelaikoma      Ne      Ne
# 78           Tvartas, laikomos vištos      Ne      Ne
# 79           Tvartas, laikomos vištos      Ne      Ne
#
# [80 rows x 15 columns]
