# %%
import pandas as pd
print("Pandas imported successfully, version: "+pd.__version__)
import scipy as sm
from scipy.stats import *
print("SciPy imported successfully, version: "+sm.__version__)
import plotly
print("Plotly imported successfully, version: "+plotly.__version__)
from plotly.graph_objs import * # for importing the different types of plots

from sklearn.decomposition import PCA #For performing principle component analysis

# The following are necessary to run plotly in an offline mode, because its otherwise an online plotting library
from plotly.graph_objs import Scatter, Layout
plotly.offline.init_notebook_mode(connected=True)
# Out:
# Pandas imported successfully, version: 0.23.4
# SciPy imported successfully, version: 1.1.0
# Plotly imported successfully, version: 3.4.0
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
#Importuoju savo rats duomenis
data_all = pd.read_csv("/home/emilija/Dokumentai/Magistras/SinBio/Sinbio-projektas/Žiurkių duomenys.csv")

# %%
#Pasiziuriu, kas cia gero
data_all
#Atrodo viskas ok
# Out:
#        Nr                  Rūšis                         Vieta  Pagavimo_data  \
# 0    R121           R.norvegicus     Joniškio raj., Veršių km.     2013.09.21
# 1    R122           R.norvegicus     Joniškio raj., Šarūnų km.     2013.09.27
# 2    R123           R.norvegicus     Panevėžio raj., Krekenava     2014.06.10
# 3    R124           R.norvegicus         Gedimino pr., Vilnius     2014.10.20
# 4    R125           R.norvegicus     Joniškio raj., Šarūnų km.    2015.02.15.
# 5    R126           R.norvegicus     Joniškio raj., Šarūnų km.    2015.02.15.
# 6    R127               R.rattus    Zarasų raj., Pakniškių km.     2015.08.13
# 7    R128               R.rattus    Zarasų raj., Pakniškių km.     2015.08.13
# 8    R129               R.rattus    Zarasų raj., Pakniškių km.     2015.08.13
# 9    R130               R.rattus    Zarasų raj., Pakniškių km.     2015.08.13
# 10   R131               R.rattus    Zarasų raj., Pakniškių km.     2015.08.13
# 11   R132               R.rattus    Zarasų raj., Pakniškių km.     2015.08.26
# 12   R133               R.rattus    Zarasų raj., Pakniškių km.     2015.08.26
# 13   R134               R.rattus    Zarasų raj., Pakniškių km.     2015.08.27
# 14   R135               R.rattus    Zarasų raj., Pakniškių km.     2015.08.27
# 15   R136               R.rattus    Zarasų raj., Pakniškių km.     2015.08.27
# 16   R137               R.rattus    Zarasų raj., Pakniškių km.     2015.08.27
# 17   R138               R.rattus    Zarasų raj., Pakniškių km.     2015.09.28
# 18   R139               R.rattus    Zarasų raj., Pakniškių km.     2015.09.28
# 19   R140               R.rattus    Zarasų raj., Pakniškių km.     2015.09.28
# 20   R141               R.rattus    Zarasų raj., Pakniškių km.     2015.09.28
# 21   R142               R.rattus    Zarasų raj., Pakniškių km.     2015.09.28
# 22   R143               R.rattus    Zarasų raj., Pakniškių km.     2015.09.28
# 23   R144               R.rattus    Zarasų raj., Pakniškių km.     2015.09.28
# 24   R145               R.rattus    Zarasų raj., Pakniškių km.     2015.09.28
# 25   R146               R.rattus    Zarasų raj., Pakniškių km.     2015.09.28
# 26   R147  R.rattus (ruda forma)   Zarasų raj., Antazavės gyv.     2015.09.28
# 27   R148  R.rattus (ruda forma)   Zarasų raj., Antazavės gyv.     2015.09.28
# 28   R149  R.rattus (ruda forma)   Zarasų raj., Antazavės gyv.     2015.10.05
# 29   R150  R.rattus (ruda forma)   Zarasų raj., Antazavės gyv.     2015.10.05
# ..    ...                    ...                           ...            ...
# 87   R208               R.rattus    Zarasų raj., Pakniškių km.     2016.11.02
# 88   R209               R.rattus    Zarasų raj., Pakniškių km.  2017.04.05-07
# 89   R210               R.rattus    Zarasų raj., Pakniškių km.  2017.04.05-07
# 90   R211               R.rattus    Zarasų raj., Pakniškių km.  2017.03.04-07
# 91   R212               R.rattus    Zarasų raj., Pakniškių km.  2017.03.04-07
# 92   R213               R.rattus    Zarasų raj., Pakniškių km.  2017.03.04-07
# 93   R214               R.rattus    Zarasų raj., Pakniškių km.     2017.03.31
# 94   R215               R.rattus    Zarasų raj., Pakniškių km.     2017.03.31
# 95   R216               R.rattus    Zarasų raj., Pakniškių km.     2017.03.31
# 96   R217               R.rattus    Zarasų raj., Pakniškių km.     2017.02.20
# 97   R218               R.rattus    Zarasų raj., Pakniškių km.     2017.02.20
# 98   R219               R.rattus    Zarasų raj., Pakniškių km.     2017.05.01
# 99   R220               R.rattus    Zarasų raj., Pakniškių km.     2017.05.01
# 100  R221               R.rattus    Zarasų raj., Pakniškių km.     2017.02.25
# 101  R222               R.rattus    Zarasų raj., Pakniškių km.     2017.07.08
# 102  R223               R.rattus    Zarasų raj., Pakniškių km.     2017.07.08
# 103  R224           R.norvegicus  Rokiškio raj., Laibgalių km.     2017.09.07
# 104  R225           R.norvegicus  Rokiškio raj., Laibgalių km.     2017.09.07
# 105  R226           R.norvegicus  Rokiškio raj., Laibgalių km.     2017.09.07
# 106  R227           R.norvegicus  Rokiškio raj., Laibgalių km.     2017.09.07
# 107  R228           R.norvegicus  Rokiškio raj., Laibgalių km.     2017.09.07
# 108  R229           R.norvegicus  Rokiškio raj., Laibgalių km.     2017.09.07
# 109  R230           R.norvegicus  Rokiškio raj., Laibgalių km.     2017.09.07
# 110  R231           R.norvegicus  Rokiškio raj., Laibgalių km.     2017.09.07
# 111  R232           R.norvegicus  Rokiškio raj., Laibgalių km.     2017.09.07
# 112  R233           R.norvegicus  Rokiškio raj., Laibgalių km.     2017.09.07
# 113  R234               R.rattus   Zarasų raj., Antazavės gyv.     2017.09.20
# 114  R235               R.rattus      Zarasų raj., Dusetų gyv.     2017.09.28
# 115  R236               R.rattus    Zarasų raj., Pakniškių km.     2017.09.30
# 116  R237               R.rattus    Zarasų raj., Pakniškių km.     2017.10.01
#
#     Lytis  Q(g.)  L(mm)  Luo(mm)  P(mm)  A(mm) Amžius  \
# 0    vyr.  162.0  187.0    152.0   38.0   15.0    ad.
# 1    vyr.  184.0  202.0    156.0   39.0   17.0    ad.
# 2    vyr.  248.0  233.0    171.0   39.0   17.0    ad.
# 3    mot.   38.0  120.0     90.0   28.0   14.0   juv.
# 4    vyr.  139.0  185.0    153.0   38.0   15.5   sub.
# 5    vyr.  148.0  187.0    170.0   36.0   16.5   sub.
# 6    mot.   69.0  144.0    162.0   35.0   22.0   sub.
# 7    mot.   92.0  155.0    182.0   36.0   21.0   sub.
# 8    vyr.   50.0  115.0    148.0   32.0   19.0   juv.
# 9    vyr.  101.0  155.0    183.0   36.0   23.0   sub.
# 10   vyr.  103.0  142.0    185.0   37.0   22.0    ad.
# 11   mot.   73.0  130.0    158.0   33.0   18.0   sub.
# 12   mot.   35.0  105.0    127.0   28.0   15.0   juv.
# 13   mot.   86.0  150.0    175.0   33.0   21.0   sub.
# 14   vyr.   56.0  137.0    154.0   31.0   19.0   juv.
# 15   vyr.   34.0  114.0    123.0   30.0   18.0   juv.
# 16   mot.   43.0  118.0    128.0   30.0   21.0   juv.
# 17   mot.   86.0  146.0    179.0   36.0   20.0   sub.
# 18   mot.   95.0  155.0    178.0   33.0   22.0   sub.
# 19   mot.   33.0  110.0    127.0   27.0   18.0   juv.
# 20   vyr.   42.0  122.0    125.0   30.0   18.0   juv.
# 21   mot.  171.0  192.0    210.0   37.0   22.0    ad.
# 22   mot.   41.0  125.0    135.0   29.0   19.0   juv.
# 23   mot.   47.0  125.0    153.0   32.0   18.0   juv.
# 24   vyr.   40.0  118.0    146.0   31.0   20.0   juv.
# 25   mot.   51.0  115.0    148.0   32.0   18.0   juv.
# 26   mot.  167.0  175.0    225.0   36.0   26.0    ad.
# 27   mot.  119.0  159.0    196.0   32.0   23.0    ad.
# 28   mot.   90.0  146.0    149.0   33.0   19.0   sub.
# 29   vyr.   69.0  144.0    162.0   32.0   21.0   sub.
# ..    ...    ...    ...      ...    ...    ...    ...
# 87   vyr.  230.0  202.0    201.0   37.0   27.0    ad.
# 88   vyr.  154.0    NaN      NaN    NaN    NaN    ad.
# 89   mot.   82.0    NaN      NaN    NaN    NaN   sub.
# 90   mot.   92.0    NaN      NaN    NaN    NaN   sub.
# 91   mot.   42.0    NaN      NaN    NaN    NaN   juv.
# 92   mot.  177.0    NaN      NaN    NaN    NaN    ad.
# 93   vyr.   75.0    NaN      NaN    NaN    NaN   juv.
# 94   vyr.   48.0    NaN      NaN    NaN    NaN   juv.
# 95   mot.   41.0    NaN      NaN    NaN    NaN   juv.
# 96   mot.  138.0    NaN      NaN    NaN    NaN    ad.
# 97   mot.   77.0    NaN      NaN    NaN    NaN   juv.
# 98   vyr.  136.0    NaN      NaN    NaN    NaN    ad.
# 99   mot.   83.0    NaN      NaN    NaN    NaN   sub.
# 100  mot.   33.0    NaN      NaN    NaN    NaN   juv.
# 101  mot.  137.0    NaN      NaN    NaN    NaN    ad.
# 102  mot.  122.0    NaN      NaN    NaN    NaN   sub.
# 103  vyr.  369.0  230.0    199.0   45.0   18.0    ad.
# 104  mot.  231.0  186.0    174.0   40.0   20.0    ad.
# 105  vyr.  384.0  245.0    200.0   47.0   20.0    ad.
# 106  mot.  286.0  209.0      NaN   40.0    NaN    ad.
# 107  vyr.  336.0  240.0    160.0   42.0   21.0    ad.
# 108  vyr.  305.0  225.0    190.0   45.0   18.0    ad.
# 109  mot.  252.0  200.0    170.0   40.0   20.0    ad.
# 110  mot.   80.0  150.0    115.0   35.0   17.0   sub.
# 111  vyr.  102.0  167.0    125.0   32.0   11.0   sub.
# 112  vyr.   73.0  145.0    120.0   35.0   18.0   juv.
# 113  mot.  104.0  165.0    160.0   32.0   20.0   sub.
# 114  mot.  130.0  170.0    176.0   35.0   19.0   sub.
# 115  mot.  137.0  170.0    195.0   36.0   25.0   sub.
# 116  vyr.   47.0  130.0    135.0   32.0   21.0   juv.
#
#                               Pastabos RatPyV1 RatPyV2
# 0    Tvartas, laikomos karvės, kiaulės     NaN     NaN
# 1    Tvartas, laikomos karvės, kiaulės     NaN     NaN
# 2                           Stumbrynas     NaN     NaN
# 3                                  NaN     NaN     NaN
# 4    Tvartas, laikomos karvės, kiaulės     NaN     NaN
# 5    Tvartas, laikomos karvės, kiaulės     NaN     NaN
# 6             Tvartas, laikomos vištos     NaN     NaN
# 7             Tvartas, laikomos vištos     NaN     NaN
# 8             Tvartas, laikomos vištos     NaN     NaN
# 9             Tvartas, laikomos vištos     NaN     NaN
# 10            Tvartas, laikomos vištos     NaN     NaN
# 11            Tvartas, laikomos vištos      Ne      Ne
# 12            Tvartas, laikomos vištos      Ne      Ne
# 13            Tvartas, laikomos vištos     NaN     NaN
# 14            Tvartas, laikomos vištos     NaN     NaN
# 15            Tvartas, laikomos vištos     NaN     NaN
# 16            Tvartas, laikomos vištos     NaN     NaN
# 17            Tvartas, laikomos vištos     NaN     NaN
# 18            Tvartas, laikomos vištos     NaN     NaN
# 19            Tvartas, laikomos vištos     NaN     NaN
# 20            Tvartas, laikomos vištos     NaN     NaN
# 21            Tvartas, laikomos vištos     NaN     NaN
# 22            Tvartas, laikomos vištos     NaN     NaN
# 23            Tvartas, laikomos vištos     NaN     NaN
# 24            Tvartas, laikomos vištos     NaN     NaN
# 25            Tvartas, laikomos vištos     NaN     NaN
# 26            Tvartas, laikomos karvės     NaN     NaN
# 27            Tvartas, laikomos karvės     NaN     NaN
# 28            Tvartas, laikomos karvės     NaN     NaN
# 29            Tvartas, laikomos karvės     NaN     NaN
# ..                                 ...     ...     ...
# 87            Tvartas, laikomos vištos      Ne      Ne
# 88            Tvartas, laikomos vištos      Ne      Ne
# 89            Tvartas, laikomos vištos      Ne      Ne
# 90            Tvartas, laikomos vištos      Ne      Ne
# 91            Tvartas, laikomos vištos      Ne      Ne
# 92            Tvartas, laikomos vištos      Ne      Ne
# 93            Tvartas, laikomos vištos      Ne      Ne
# 94            Tvartas, laikomos vištos      Ne      Ne
# 95            Tvartas, laikomos vištos      Ne      Ne
# 96            Tvartas, laikomos vištos      Ne      Ne
# 97            Tvartas, laikomos vištos      Ne      Ne
# 98            Tvartas, laikomos vištos      Ne      Ne
# 99            Tvartas, laikomos vištos      Ne      Ne
# 100           Tvartas, laikomos vištos      Ne      Ne
# 101           Tvartas, laikomos vištos      Ne      Ne
# 102           Tvartas, laikomos vištos      Ne      Ne
# 103                         Paukštynas      Ne      Ne
# 104                         Paukštynas      Ne      Ne
# 105                         Paukštynas    Taip      Ne
# 106                         Paukštynas      Ne    Taip
# 107                         Paukštynas      Ne      Ne
# 108                         Paukštynas      Ne      Ne
# 109                         Paukštynas    Taip      Ne
# 110                         Paukštynas      Ne      Ne
# 111                         Paukštynas      Ne      Ne
# 112                         Paukštynas      Ne      Ne
# 113           Tvartas, laikomos karvės      Ne      Ne
# 114  Ūkinis pastatas, gyvūnų nelaikoma      Ne      Ne
# 115           Tvartas, laikomos vištos      Ne      Ne
# 116           Tvartas, laikomos vištos      Ne      Ne
#
# [117 rows x 14 columns]

# %%
data_all.describe()
# Out:
#             Q(g.)       L(mm)     Luo(mm)       P(mm)      A(mm)
# count  116.000000   99.000000   99.000000  101.000000  98.000000
# mean   133.051724  162.505051  163.242424   34.613861  19.071429
# std    105.803661   41.482323   31.405216    5.083248   3.064597
# min     10.000000   88.000000   90.000000   23.000000  11.000000
# 25%     50.750000  128.000000  135.000000   31.000000  17.000000
# 50%    101.500000  161.000000  166.000000   35.000000  19.000000
# 75%    168.000000  189.500000  186.500000   38.000000  21.000000
# max    435.000000  249.000000  231.000000   47.000000  27.000000

# %%
data_all.describe(include='all')
# Out:
#           Nr     Rūšis                       Vieta Pagavimo_data Lytis  \
# count    117       117                         117           117   112
# unique   117         3                          14            45     2
# top     R187  R.rattus  Zarasų raj., Pakniškių km.    2015.09.28  mot.
# freq       1        78                          68            11    57
# mean     NaN       NaN                         NaN           NaN   NaN
# std      NaN       NaN                         NaN           NaN   NaN
# min      NaN       NaN                         NaN           NaN   NaN
# 25%      NaN       NaN                         NaN           NaN   NaN
# 50%      NaN       NaN                         NaN           NaN   NaN
# 75%      NaN       NaN                         NaN           NaN   NaN
# max      NaN       NaN                         NaN           NaN   NaN
#
#              Q(g.)       L(mm)     Luo(mm)       P(mm)      A(mm) Amžius  \
# count   116.000000   99.000000   99.000000  101.000000  98.000000    117
# unique         NaN         NaN         NaN         NaN        NaN      3
# top            NaN         NaN         NaN         NaN        NaN    ad.
# freq           NaN         NaN         NaN         NaN        NaN     45
# mean    133.051724  162.505051  163.242424   34.613861  19.071429    NaN
# std     105.803661   41.482323   31.405216    5.083248   3.064597    NaN
# min      10.000000   88.000000   90.000000   23.000000  11.000000    NaN
# 25%      50.750000  128.000000  135.000000   31.000000  17.000000    NaN
# 50%     101.500000  161.000000  166.000000   35.000000  19.000000    NaN
# 75%     168.000000  189.500000  186.500000   38.000000  21.000000    NaN
# max     435.000000  249.000000  231.000000   47.000000  27.000000    NaN
#
#                         Pastabos RatPyV1 RatPyV2
# count                        115      84      84
# unique                         9       2       2
# top     Tvartas, laikomos vištos      Ne      Ne
# freq                          61      75      79
# mean                         NaN     NaN     NaN
# std                          NaN     NaN     NaN
# min                          NaN     NaN     NaN
# 25%                          NaN     NaN     NaN
# 50%                          NaN     NaN     NaN
# 75%                          NaN     NaN     NaN
# max                          NaN     NaN     NaN

# %%
data_all.Rūšis.describe()
# Out:
# count          117
# unique           3
# top       R.rattus
# freq            78
# Name: Rūšis, dtype: object

# %%
data_all.Vieta.describe()
# Out:
# count                            117
# unique                            14
# top       Zarasų raj., Pakniškių km.
# freq                              68
# Name: Vieta, dtype: object

# %%
data_all.Lytis.describe()
# Out:
# count      112
# unique       2
# top       mot.
# freq        57
# Name: Lytis, dtype: object

# %%
data_all.Amžius.describe()
# Out:
# count     117
# unique      3
# top       ad.
# freq       45
# Name: Amžius, dtype: object

# %%
data_all.iloc[:,3].describe()
# Out:
# count            117
# unique            45
# top       2015.09.28
# freq              11
# Name: Pagavimo_data, dtype: object

# %%
data_all.Pastabos.describe()
# Out:
# count                          115
# unique                           9
# top       Tvartas, laikomos vištos
# freq                            61
# Name: Pastabos, dtype: object

# %%
data_all.RatPyV1.describe()
# Out:
# count     84
# unique     2
# top       Ne
# freq      75
# Name: RatPyV1, dtype: object

# %%
data_all.RatPyV2.describe()
# Out:
# count     84
# unique     2
# top       Ne
# freq      79
# Name: RatPyV2, dtype: object

# %%
data_all.Pagavimo_data.min()
# Out:
# '2013.09.21'

# %%
data_all.Pagavimo_data.max()
# Out:
# '2017.10.01'

# %%
data_all.head()
# Out:
#      Nr         Rūšis                      Vieta Pagavimo_data Lytis  Q(g.)  \
# 0  R121  R.norvegicus  Joniškio raj., Veršių km.    2013.09.21  vyr.  162.0
# 1  R122  R.norvegicus  Joniškio raj., Šarūnų km.    2013.09.27  vyr.  184.0
# 2  R123  R.norvegicus  Panevėžio raj., Krekenava    2014.06.10  vyr.  248.0
# 3  R124  R.norvegicus      Gedimino pr., Vilnius    2014.10.20  mot.   38.0
# 4  R125  R.norvegicus  Joniškio raj., Šarūnų km.   2015.02.15.  vyr.  139.0
#
#    L(mm)  Luo(mm)  P(mm)  A(mm) Amžius                           Pastabos  \
# 0  187.0    152.0   38.0   15.0    ad.  Tvartas, laikomos karvės, kiaulės
# 1  202.0    156.0   39.0   17.0    ad.  Tvartas, laikomos karvės, kiaulės
# 2  233.0    171.0   39.0   17.0    ad.                         Stumbrynas
# 3  120.0     90.0   28.0   14.0   juv.                                NaN
# 4  185.0    153.0   38.0   15.5   sub.  Tvartas, laikomos karvės, kiaulės
#
#   RatPyV1 RatPyV2
# 0     NaN     NaN
# 1     NaN     NaN
# 2     NaN     NaN
# 3     NaN     NaN
# 4     NaN     NaN

# %%
data_all.Nr.min()
# Out:
# 'R121'

# %%
data_all.Nr.max()
# Out:
# 'R237'

# %%
data_all.Nr.count()
# Out:
# 117

# %%
data_all.Rūšis.unique()
# Out:
# array(['R.norvegicus', 'R.rattus', 'R.rattus (ruda forma)'], dtype=object)

# %%
data_all.Vieta.unique()
# Out:
# array(['Joniškio raj., Veršių km.', 'Joniškio raj., Šarūnų km.',
#        'Panevėžio raj., Krekenava', 'Gedimino pr., Vilnius',
#        'Zarasų raj., Pakniškių km.', 'Zarasų raj., Antazavės gyv.',
#        'Zarasų raj., Dusetų gyv.', 'Utenos raj., Vilučių km.',
#        'Vilniaus raj.', 'Grubupių km., Šilutės raj. ',
#        'Vilnius, senamiestis', 'Vilnius, Gedimino pr.',
#        'Rokiškio raj., Kovelių km.', 'Rokiškio raj., Laibgalių km.'],
#       dtype=object)

# %%
data_all.Vieta.describe()
# Out:
# count                            117
# unique                            14
# top       Zarasų raj., Pakniškių km.
# freq                              68
# Name: Vieta, dtype: object

# %%
data_all.Pagavimo_data.describe()
# Out:
# count            117
# unique            45
# top       2015.09.28
# freq              11
# Name: Pagavimo_data, dtype: object

# %%
data_all.Vieta.isna().sum()
# Out:
# 0

# %%
data_all.Lytis.isna().sum()
# Out:
# 5

# %%
data_all.Amžius.unique()
# Out:
# array(['ad.', 'juv.', 'sub.'], dtype=object)

# %%
data_all.Amžius.value_counts()
# Out:
# ad.     45
# juv.    43
# sub.    29
# Name: Amžius, dtype: int64

# %%
data_all.Amžius.isna().sum()
# Out:
# 0

# %%
data_all.Rūšis.value_counts()
# Out:
# R.rattus                 78
# R.norvegicus             33
# R.rattus (ruda forma)     6
# Name: Rūšis, dtype: int64

# %%
data_all.Vieta.value_counts()
# Out:
# Zarasų raj., Pakniškių km.      68
# Zarasų raj., Antazavės gyv.     13
# Rokiškio raj., Laibgalių km.    10
# Grubupių km., Šilutės raj.       6
# Joniškio raj., Šarūnų km.        6
# Vilniaus raj.                    4
# Zarasų raj., Dusetų gyv.         2
# Rokiškio raj., Kovelių km.       2
# Vilnius, Gedimino pr.            1
# Joniškio raj., Veršių km.        1
# Gedimino pr., Vilnius            1
# Vilnius, senamiestis             1
# Panevėžio raj., Krekenava        1
# Utenos raj., Vilučių km.         1
# Name: Vieta, dtype: int64

# %%
data_all.Pagavimo_data.value_counts()
# Out:
# 2015.09.28          11
# 2017.09.07          10
# 2015.10.05           7
# 2016.08.31           6
# 2014.01.03           6
# 2016.09.27           5
# 2015.08.13           5
# 2015.08.27           4
# 2016.01.09           4
# 2015.10.13           4
# 2015.10.14           3
# 2017.03.04-07        3
# 2017.03.31           3
# 2015.10.02           3
# 2014.11.05           2
# 2016.04.01           2
# 2015.02.15.          2
# 2017.07.08           2
# 2015.10.03           2
# 2016.01.10           2
# 2017.02.20           2
# 2016.09.15           2
# 2015.10.12           2
# 2017.04.05-07        2
# 2015.08.26           2
# 2017.05.01           2
# 2017.09.30           1
# 2013.09.27           1
# 2017.10.01           1
# 2015.03              1
# 2014.10.20           1
# 2016.11.02           1
# 2017.02.25           1
# 2015.02.17           1
# 2016.02.05           1
# 2015.02.16           1
# 2017.09.28           1
# 2014.06.10           1
# 2014.09.29-10.22     1
# 2014.11.17           1
# 2014.11.06           1
# 2015.02.15           1
# 2014.09.29-10.21     1
# 2017.09.20           1
# 2013.09.21           1
# Name: Pagavimo_data, dtype: int64

# %%
data_all.Lytis.value_counts()
# Out:
# mot.    57
# vyr.    55
# Name: Lytis, dtype: int64

# %%
data_all.Amžius.value_counts()
# Out:
# ad.     45
# juv.    43
# sub.    29
# Name: Amžius, dtype: int64

# %%
data_all.Pastabos.value_counts()
# Out:
# Tvartas, laikomos vištos             61
# Tvartas, laikomos karvės             15
# Paukštynas                           12
# Tvartas, laikomos karvės, kiaulės     7
# Gyvenamasis namas                     7
# Kiaulių auginimo kompleksas           6
# Tvartas, laikomos kiaulės             4
# Ūkinis pastatas, gyvūnų nelaikoma     2
# Stumbrynas                            1
# Name: Pastabos, dtype: int64

# %%
data_all.Pastabos.isna().sum()
# Out:
# 2

# %%
data_all.RatPyV1.isna().sum()
# Out:
# 33

# %%
data_all.RatPyV1.value_counts()
# Out:
# Ne      75
# Taip     9
# Name: RatPyV1, dtype: int64

# %%
data_all.RatPyV2.value_counts()
# Out:
# Ne      79
# Taip     5
# Name: RatPyV2, dtype: int64

# %%
data_all.RatPyV2.isna().sum()
# Out:
# 33

# %%
data_all.Pastabos.unique()
# Out:
# array(['Tvartas, laikomos karvės, kiaulės', 'Stumbrynas', nan,
#        'Tvartas, laikomos vištos', 'Tvartas, laikomos karvės',
#        'Ūkinis pastatas, gyvūnų nelaikoma', 'Gyvenamasis namas',
#        'Tvartas, laikomos kiaulės', 'Kiaulių auginimo kompleksas',
#        'Paukštynas'], dtype=object)
